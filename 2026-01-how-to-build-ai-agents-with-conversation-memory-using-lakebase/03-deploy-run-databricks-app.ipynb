# %% [markdown]
# ## Databricks App Deployment - [Databricks SDK for Python](https://databricks-sdk-py.readthedocs.io/en/latest/workspace/apps/apps.html#w-apps-apps)
# - Please keep in mind you can also use [Databricks Asset Bundles](https://docs.databricks.com/aws/en/dev-tools/bundles/resources#app) to deploy an `app` as well

# %%
# %pip install -qqqq -U databricks-sdk
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
dbutils.widgets.text("app_name", "bo-lakebase-memory-app", "app_name")
dbutils.widgets.text(
    "source_code_path",
    "/Workspace/Users/bo.cheng@databricks.com/bo-cheng-dnb-demos-personal/lakebase-memory-accelerator/databricks_apps/streamlit-chatbot-app",
    "source_code_path",
)

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()

# %%
from databricks.sdk.service.apps import App

app = App(
    name=dbutils.widgets.get("app_name"),
    description="example Databricks App to integrate with KA serving endpoint",
    user_api_scopes=["serving.serving-endpoints"],
)
w.apps.create_and_wait(app=app)
# Out:
# App(name='bo-lakebase-memory-app-blog', active_deployment=None, app_status=ApplicationStatus(message='App has status: App has not been deployed yet. Run your app by deploying source code', state=<ApplicationState.UNAVAILABLE: 'UNAVAILABLE'>), budget_policy_id=None, compute_status=ComputeStatus(message='App compute is running.', state=<ComputeState.ACTIVE: 'ACTIVE'>), create_time='2026-01-08T21:40:00Z', creator='bo.cheng@databricks.com', default_source_code_path='', description='example Databricks App to integrate with KA serving endpoint', effective_budget_policy_id='', effective_user_api_scopes=['iam.current-user:read', 'serving.serving-endpoints', 'iam.access-control:read'], id='ee16e127-d9d5-48f0-b350-4c08ca4b0732', oauth2_app_client_id='357c4077-6d38-4907-ae5a-ef850e96eb15', oauth2_app_integration_id='357c4077-6d38-4907-ae5a-ef850e96eb15', pending_deployment=None, resources=[], service_principal_client_id='ee16e127-d9d5-48f0-b350-4c08ca4b0732', service_principal_id=74806834790771, service_principal_name='app-40zbx9 bo-lakebase-memory-app-blog', update_time='2026-01-08T21:42:18Z', updater='bo.cheng@databricks.com', url='https://bo-lakebase-memory-app-blog-1444828305810485.aws.databricksapps.com', user_api_scopes=['serving.serving-endpoints'])

# %%
from databricks.sdk.service.apps import AppDeployment

# replace source_code_path with your own
app_deployment = AppDeployment(
    source_code_path=dbutils.widgets.get("source_code_path")
)
w.apps.deploy_and_wait(
    app_name=dbutils.widgets.get("app_name"), app_deployment=app_deployment
)
# Out:
# AppDeployment(create_time='2026-01-08T21:56:59Z', creator='bo.cheng@databricks.com', deployment_artifacts=AppDeploymentArtifacts(source_code_path='/Workspace/Users/ee16e127-d9d5-48f0-b350-4c08ca4b0732/src/01f0ecdcf4ec19b5a9e076ad547e9dda'), deployment_id='01f0ecdcf4ec19b5a9e076ad547e9dda', mode=<AppDeploymentMode.SNAPSHOT: 'SNAPSHOT'>, source_code_path='/Workspace/Users/bo.cheng@databricks.com/bo-cheng-dnb-demos-personal/lakebase-memory-accelerator/databricks_apps/streamlit-chatbot-app', status=AppDeploymentStatus(message='App started successfully', state=<AppDeploymentState.SUCCEEDED: 'SUCCEEDED'>), update_time='2026-01-08T21:57:03Z')
